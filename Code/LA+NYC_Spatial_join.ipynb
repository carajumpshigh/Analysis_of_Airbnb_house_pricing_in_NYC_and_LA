# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import rtree
import math

# %% [markdown]
# # Los Angeles

# %% [markdown]
# ## 0. Import data

# %%
# Airbnb listings data
listings_LA = pd.read_csv('data/LosAngeles/filtered_listings_LA.csv')
listings_LA.head()
# Out:
#    Unnamed: 0    id                        listing_url       scrape_id  \
# 0         0.0   109   https://www.airbnb.com/rooms/109  20200213032707
# 1         1.0   344   https://www.airbnb.com/rooms/344  20200213032707
# 2         2.0  2708  https://www.airbnb.com/rooms/2708  20200213032707
# 3         3.0  2732  https://www.airbnb.com/rooms/2732  20200213032707
# 4         4.0  2864  https://www.airbnb.com/rooms/2864  20200213032707
#
#   last_scraped                                               name  \
# 0   2020-02-13  Amazing bright elegant condo park front *UPGRA...
# 1   2020-02-13                  Family perfect;Pool;Near Studios!
# 2   2020-02-13  Mirrored Mini-Suite with Fireplace - W. Hollywood
# 3   2020-02-13                              Zen Life at the Beach
# 4   2020-02-13  *Upscale Professional Home with Beautiful Studio*
#
#                                              summary  \
# 0  *** Unit upgraded with new bamboo flooring, br...
# 1  This home is perfect for families; aspiring ch...
# 2  Our best memory foam pillows you'll ever sleep...
# 3                                                NaN
# 4  Centrally located.... Furnished with 42 inch S...
#
#                                                space  \
# 0  *** Unit upgraded with new bamboo flooring, br...
# 1  Cheerful & comfortable; near studios, amusemen...
# 2  Flickering fireplace.  Blendtec® Designer 625 ...
# 3  This is a three story townhouse with the follo...
# 4  The space is furnished with Thomasville furnit...
#
#                                          description experiences_offered  ...  \
# 0  *** Unit upgraded with new bamboo flooring, br...                none  ...
# 1  This home is perfect for families; aspiring ch...                none  ...
# 2  Our best memory foam pillows you'll ever sleep...                none  ...
# 3  This is a three story townhouse with the follo...                none  ...
# 4  Centrally located.... Furnished with 42 inch S...                none  ...
#
#   instant_bookable is_business_travel_ready          cancellation_policy  \
# 0                f                        f  strict_14_with_grace_period
# 1                t                        f                     flexible
# 2                t                        f  strict_14_with_grace_period
# 3                f                        f  strict_14_with_grace_period
# 4                f                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             t                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                            1.0                                         1.0
# 1                            1.0                                         1.0
# 2                            2.0                                         0.0
# 3                            2.0                                         1.0
# 4                            1.0                                         1.0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                          0.0
# 1                                          0.0
# 2                                          2.0
# 3                                          1.0
# 4                                          0.0
#
#   calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                         0.0               0.02
# 1                                         0.0               0.18
# 2                                         0.0               0.33
# 3                                         0.0               0.20
# 4                                         0.0                NaN
#
# [5 rows x 107 columns]

# %%
#create geodataframe based on longitude and latitude
gdf_listings_LA = gpd.GeoDataFrame(listings_LA, geometry=gpd.points_from_xy(listings_LA.longitude, listings_LA.latitude))
gdf_listings_LA.head()
# Out:
#    Unnamed: 0    id                        listing_url       scrape_id  \
# 0         0.0   109   https://www.airbnb.com/rooms/109  20200213032707
# 1         1.0   344   https://www.airbnb.com/rooms/344  20200213032707
# 2         2.0  2708  https://www.airbnb.com/rooms/2708  20200213032707
# 3         3.0  2732  https://www.airbnb.com/rooms/2732  20200213032707
# 4         4.0  2864  https://www.airbnb.com/rooms/2864  20200213032707
#
#   last_scraped                                               name  \
# 0   2020-02-13  Amazing bright elegant condo park front *UPGRA...
# 1   2020-02-13                  Family perfect;Pool;Near Studios!
# 2   2020-02-13  Mirrored Mini-Suite with Fireplace - W. Hollywood
# 3   2020-02-13                              Zen Life at the Beach
# 4   2020-02-13  *Upscale Professional Home with Beautiful Studio*
#
#                                              summary  \
# 0  *** Unit upgraded with new bamboo flooring, br...
# 1  This home is perfect for families; aspiring ch...
# 2  Our best memory foam pillows you'll ever sleep...
# 3                                                NaN
# 4  Centrally located.... Furnished with 42 inch S...
#
#                                                space  \
# 0  *** Unit upgraded with new bamboo flooring, br...
# 1  Cheerful & comfortable; near studios, amusemen...
# 2  Flickering fireplace.  Blendtec® Designer 625 ...
# 3  This is a three story townhouse with the follo...
# 4  The space is furnished with Thomasville furnit...
#
#                                          description experiences_offered  ...  \
# 0  *** Unit upgraded with new bamboo flooring, br...                none  ...
# 1  This home is perfect for families; aspiring ch...                none  ...
# 2  Our best memory foam pillows you'll ever sleep...                none  ...
# 3  This is a three story townhouse with the follo...                none  ...
# 4  Centrally located.... Furnished with 42 inch S...                none  ...
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f                     flexible
# 2                        f  strict_14_with_grace_period
# 3                        f  strict_14_with_grace_period
# 4                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             t                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                            1.0                                         1.0
# 1                            1.0                                         1.0
# 2                            2.0                                         0.0
# 3                            2.0                                         1.0
# 4                            1.0                                         1.0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                          0.0
# 1                                          0.0
# 2                                          2.0
# 3                                          1.0
# 4                                          0.0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month  \
# 0                                         0.0              0.02
# 1                                         0.0              0.18
# 2                                         0.0              0.33
# 3                                         0.0              0.20
# 4                                         0.0               NaN
#
#                       geometry
# 0  POINT (-118.38494 33.98209)
# 1  POINT (-118.33458 34.16562)
# 2  POINT (-118.34602 34.09768)
# 3  POINT (-118.48127 34.00475)
# 4  POINT (-118.11397 33.87619)
#
# [5 rows x 108 columns]

# %%
#read shapefiles of LA Council District
district_LA =gpd.read_file('data/LosAngeles/Council_Districts/geo_export_e9d7a721-6664-49f6-a403-e70598dc8734.shp')
district_LA.head()
# Out:
#              dist_name  district             name  objectid  \
# 0  1 - Gilbert Cedillo       1.0  Gilbert Cedillo       1.0
# 1   2 - Paul Krekorian       2.0   Paul Krekorian       2.0
# 2  3 - Bob Blumenfield       3.0  Bob Blumenfield       3.0
# 3        4 - David Ryu       4.0        David Ryu       4.0
# 4      5 - Paul Koretz       5.0      Paul Koretz       5.0
#
#                                             geometry
# 0  POLYGON ((-118.26853 34.04664, -118.26878 34.0...
# 1  POLYGON ((-118.33732 34.22103, -118.33455 34.2...
# 2  POLYGON ((-118.51860 34.20840, -118.51859 34.2...
# 3  POLYGON ((-118.43998 34.17939, -118.43998 34.1...
# 4  POLYGON ((-118.51848 34.18661, -118.51849 34.1...

# %% [markdown]
# ## 1. Map census data to each district

# %%
# import census data
census_LA = pd.read_csv('data/LosAngeles/Economy_Panel_LA.csv')
census_LA.head()
# Out:
#            category                         indicator  \
# 0  BUILDING PERMITS             MIX-USE PERMIT VALUES
# 1     TAXABLE SALES           TAXABLE SALES BY SECTOR
# 2        EMPLOYMENT                  TOTAL EMPLOYMENT
# 3        EMPLOYMENT  ESTABLISHMENT CHANGE BY INDUSTRY
# 4        EMPLOYMENT  ESTABLISHMENT CHANGE BY INDUSTRY
#
#                               sub_indicator            locality gender  \
# 0                                       NaN    LOS ANGELES CITY    NaN
# 1  CLOTHING AND CLOTHING ACCESSORIES STORES  LOS ANGELES COUNTY    NaN
# 2                      TOTAL ALL INDUSTRIES    LOS ANGELES CITY    NaN
# 3                             MANUFACTURING    LOS ANGELES CITY    NaN
# 4                          EDUCATION/HEALTH    LOS ANGELES CITY    NaN
#
#   council_district  fiscal_year   fy_qtr  calendar_year   cy_qtr  \
# 0       CITY TOTAL       2014.0  2014-03         2014.0  2014-01
# 1              NaN       2013.0  2013-03         2013.0  2013-01
# 2                6       2014.0  2014-03         2014.0  2014-01
# 3               10       2013.0  2013-01         2012.0  2012-03
# 4               12       2014.0  2014-02         2013.0  2013-04
#
#   quarter_start  as_of_date unit_of_measure                         unit_text  \
# 0      1-1-2014  04-11-2017               $  SEASONALLY ADJUSTED AND SMOOTHED
# 1      1-1-2013  04-11-2017               $    THOUSANDS, SEASONALLY ADJUSTED
# 2      1-1-2014  04-11-2017               #               SEASONALLY ADJUSTED
# 3      7-1-2012  04-11-2017               #                               NaN
# 4     10-1-2013  04-11-2017               #                               NaN
#
#          value                                             source
# 0  229500000.0  CITY OF LOS ANGELES DEPARTMENT OF BUILDING AND...
# 1    2485844.7                              BOARD OF EQUALIZATION
# 2      79722.0  EMPLOYMENT DEVELOPMENT DEPARTMENT, BEACON ECON...
# 3          0.0  EMPLOYMENT DEVELOPMENT DEPARTMENT, BEACON ECON...
# 4         23.0  EMPLOYMENT DEVELOPMENT DEPARTMENT, BEACON ECON...

# %%
# population in each council district
population_LA = census_LA[(census_LA.indicator=='POPULATION') & (census_LA.calendar_year==2015)] \
                [['indicator','council_district','value']] \
                .sort_values(by='council_district')[:15] \
                .set_index(['council_district'])[['value']]
population_LA
# Out:
#                       value
# council_district
# 1                 251630.14
# 10                238959.80
# 11                284703.41
# 12                292429.38
# 13                255723.30
# 14                246860.28
# 15                278403.91
# 2                 254059.22
# 3                 273149.06
# 4                 252310.55
# 5                 257749.05
# 6                 274551.28
# 7                 272492.78
# 8                 257865.50
# 9                 281008.38

# %%
# calculate the education indicator (percentage of population with education experience over high school in each council district)
less_than_high_school_LA = pd.pivot_table(census_LA[(census_LA.sub_indicator=='LESS THAN HIGH SCHOOL') & (census_LA.calendar_year==2015)] \
                               ,index='council_district',values='value',aggfunc=np.sum)[:15]
education_LA = pd.DataFrame([[less_than_high_school_LA.index[i],1-less_than_high_school_LA.value[i]/ population_LA.value[i]] \
                             for i in range(len(education_LA))],columns=['council_district','education'])

education_LA['council_district'] = education_LA['council_district'].astype(float)

education_LA = education_LA.set_index(['council_district'])
education_LA
# Out:
#                   education
# council_district
# 1.0                0.731226
# 10.0               0.825997
# 11.0               0.948697
# 12.0               0.928378
# 13.0               0.812804
# 14.0               0.774235
# 15.0               0.816979
# 2.0                0.866765
# 3.0                0.875585
# 4.0                0.958282
# 5.0                0.960307
# 6.0                0.783831
# 7.0                0.794188
# 8.0                0.798571
# 9.0                0.716395

# %%
# collect the income indicator (median household income in each council district)
income_LA = census_LA[(census_LA.indicator=='MEDIAN HOUSEHOLD INCOME') & (census_LA.calendar_year==2015)] \
                     [['indicator','council_district','value']] \
                     .sort_values(by='council_district')[:15]

income_LA['council_district'] = income_LA['council_district'].astype(float)

income_LA = income_LA.set_index(['council_district'])[['value']] \
                     .rename(columns={'value':'income'})
income_LA
# Out:
#                      income
# council_district
# 1.0               41130.591
# 10.0              43107.776
# 11.0              85136.396
# 12.0              73395.883
# 13.0              43768.291
# 14.0              39769.124
# 15.0              48199.181
# 2.0               58509.697
# 3.0               71327.406
# 4.0               66771.866
# 5.0               69213.955
# 6.0               50486.744
# 7.0               57166.759
# 8.0               35758.970
# 9.0               33327.804

# %%
# map census data with council districts
district_census_LA = district_LA.merge(income_LA, left_on='district', right_index=True) \
                                .merge(education_LA, left_on='district', right_index=True)
district_census_LA
# Out:
#                       dist_name  district                     name  objectid  \
# 0           1 - Gilbert Cedillo       1.0          Gilbert Cedillo       1.0
# 1            2 - Paul Krekorian       2.0           Paul Krekorian       2.0
# 2           3 - Bob Blumenfield       3.0          Bob Blumenfield       3.0
# 3                 4 - David Ryu       4.0                David Ryu       4.0
# 4               5 - Paul Koretz       5.0              Paul Koretz       5.0
# 5             6 - Nury Martinez       6.0            Nury Martinez       6.0
# 6          7 - Monica Rodriguez       7.0         Monica Rodriguez       7.0
# 7   8 - Marqueece Harris-Dawson       8.0  Marqueece Harris-Dawson       8.0
# 8       9 - Curren D. Price Jr.       9.0      Curren D. Price Jr.       9.0
# 9       10 - Herb J. Wesson Jr.      10.0       Herb J. Wesson Jr.      10.0
# 10              11 - Mike Bonin      11.0               Mike Bonin      11.0
# 11                12 - John Lee      12.0                 John Lee      12.0
# 12         13 - Mitch O'Farrell      13.0          Mitch O'Farrell      13.0
# 13             14 - Jose Huizar      14.0              Jose Huizar      14.0
# 14            15 - Joe Buscaino      15.0             Joe Buscaino      15.0
#
#                                              geometry     income  education
# 0   POLYGON ((-118.26853 34.04664, -118.26878 34.0...  41130.591   0.731226
# 1   POLYGON ((-118.33732 34.22103, -118.33455 34.2...  58509.697   0.866765
# 2   POLYGON ((-118.51860 34.20840, -118.51859 34.2...  71327.406   0.875585
# 3   POLYGON ((-118.43998 34.17939, -118.43998 34.1...  66771.866   0.958282
# 4   POLYGON ((-118.51848 34.18661, -118.51849 34.1...  69213.955   0.960307
# 5   POLYGON ((-118.36533 34.22870, -118.36417 34.2...  50486.744   0.783831
# 6   POLYGON ((-118.33732 34.22103, -118.33732 34.2...  57166.759   0.794188
# 7   POLYGON ((-118.30027 34.03694, -118.29635 34.0...  35758.970   0.798571
# 8   POLYGON ((-118.23975 34.01479, -118.23976 34.0...  33327.804   0.716395
# 9   POLYGON ((-118.28431 34.06371, -118.28420 34.0...  43107.776   0.825997
# 10  POLYGON ((-118.45952 34.06547, -118.45951 34.0...  85136.396   0.948697
# 11  POLYGON ((-118.47297 34.23193, -118.47301 34.2...  73395.883   0.928378
# 12  POLYGON ((-118.23879 34.12623, -118.23879 34.1...  43768.291   0.812804
# 13  POLYGON ((-118.23975 34.01479, -118.23974 34.0...  39769.124   0.774235
# 14  POLYGON ((-118.29167 33.92850, -118.29166 33.9...  48199.181   0.816979

# %% [markdown]
# ## 2. Spatial join listings data with census data

# %%
# spatial joint
gdf_listings_LA.crs = district_census_LA.crs
listings_with_edu_income = gpd.sjoin(gdf_listings_LA, district_census_LA, how="inner", op="intersects")
listings_with_edu_income.head()
# Out:
#     Unnamed: 0     id                         listing_url       scrape_id  \
# 2          2.0   2708   https://www.airbnb.com/rooms/2708  20200213032707
# 9          9.0   6931   https://www.airbnb.com/rooms/6931  20200213032707
# 20        20.0  12320  https://www.airbnb.com/rooms/12320  20200213032707
# 22        22.0  14098  https://www.airbnb.com/rooms/14098  20200213032707
# 33        33.0  20786  https://www.airbnb.com/rooms/20786  20200213032707
#
#    last_scraped                                          name_left  \
# 2    2020-02-13  Mirrored Mini-Suite with Fireplace - W. Hollywood
# 9    2020-02-13  Off Sunset Wrap-Around Terr Runyon Canyon View...
# 20   2020-02-13                    1930's Spanish Duplex on 9th St
# 22   2020-02-13  Glamour Calls Us A Haven of Peace, Modern Arch...
# 33   2020-02-13                     MONDRIAN LIKE SKY HIGH STUDIO!
#
#                                               summary  \
# 2   Our best memory foam pillows you'll ever sleep...
# 9   Our best memory foam pillows; you'll ever slee...
# 20  My place is close to Miracle Mile, Republique,...
# 22  Roll up the wall at the foot of the bed and le...
# 33                                                NaN
#
#                                                 space  \
# 2   Flickering fireplace.  Blendtec® Designer 625 ...
# 9   Decorated with fresh flowers for the Holidays....
# 20  Fabulous (Phone number hidden by Airbnb) 's 2B...
# 22  RATED #1 FOR short / long term specialty accom...
# 33  Need a GREAT spot with superior peace and priv...
#
#                                           description experiences_offered  \
# 2   Our best memory foam pillows you'll ever sleep...                none
# 9   Our best memory foam pillows; you'll ever slee...                none
# 20  My place is close to Miracle Mile, Republique,...                none
# 22  Roll up the wall at the foot of the bed and le...                none
# 33  Need a GREAT spot with superior peace and priv...                none
#
#     ... calculated_host_listings_count_shared_rooms reviews_per_month  \
# 2   ...                                         0.0              0.33
# 9   ...                                         0.0              0.14
# 20  ...                                         0.0              0.54
# 22  ...                                         0.0              0.24
# 33  ...                                         0.0              0.28
#
#                        geometry index_right      dist_name district  \
# 2   POINT (-118.34602 34.09768)           3  4 - David Ryu      4.0
# 9   POINT (-118.34801 34.09521)           3  4 - David Ryu      4.0
# 20  POINT (-118.34352 34.05864)           3  4 - David Ryu      4.0
# 22  POINT (-118.32056 34.11959)           3  4 - David Ryu      4.0
# 33  POINT (-118.32044 34.11939)           3  4 - David Ryu      4.0
#
#    name_right objectid     income  education
# 2   David Ryu      4.0  66771.866   0.958282
# 9   David Ryu      4.0  66771.866   0.958282
# 20  David Ryu      4.0  66771.866   0.958282
# 22  David Ryu      4.0  66771.866   0.958282
# 33  David Ryu      4.0  66771.866   0.958282
#
# [5 rows x 115 columns]

# %% [markdown]
# ## 3. Calculate crime indicator

# %%
crime_LA = pd.read_csv('data/LosAngeles/LA_2019_Arrest.csv')
crime_LA
# Out:
#       Arrest Date              Location
# 0      2019-05-03  (33.9543, -118.2827)
# 1      2019-04-29  (34.0508, -118.4592)
# 2      2019-11-23  (34.0477, -118.2047)
# 3      2019-04-30  (34.0907, -118.3384)
# 4      2019-04-30  (34.2149, -118.4674)
# ...           ...                   ...
# 93436  2019-04-27   (33.778, -118.2727)
# 93437  2019-04-27  (34.2156, -118.5975)
# 93438  2019-04-27  (34.0483, -118.2631)
# 93439  2019-04-27  (34.2248, -118.4967)
# 93440  2019-04-27   (33.942, -118.2739)
#
# [93441 rows x 2 columns]

# %%
# split the latitude and longitude
crime_LA['latitude'] = [float(i.replace('(', '').replace(')', '').split(", ")[0]) for i in crime_LA.Location]
crime_LA['longitude'] = [float(i.replace('(', '').replace(')', '').split(", ")[1]) for i in crime_LA.Location]
crime_LA
# Out:
#       Arrest Date              Location  latitude  longitude
# 0      2019-05-03  (33.9543, -118.2827)   33.9543  -118.2827
# 1      2019-04-29  (34.0508, -118.4592)   34.0508  -118.4592
# 2      2019-11-23  (34.0477, -118.2047)   34.0477  -118.2047
# 3      2019-04-30  (34.0907, -118.3384)   34.0907  -118.3384
# 4      2019-04-30  (34.2149, -118.4674)   34.2149  -118.4674
# ...           ...                   ...       ...        ...
# 93436  2019-04-27   (33.778, -118.2727)   33.7780  -118.2727
# 93437  2019-04-27  (34.2156, -118.5975)   34.2156  -118.5975
# 93438  2019-04-27  (34.0483, -118.2631)   34.0483  -118.2631
# 93439  2019-04-27  (34.2248, -118.4967)   34.2248  -118.4967
# 93440  2019-04-27   (33.942, -118.2739)   33.9420  -118.2739
#
# [93441 rows x 4 columns]

# %%
# create geodataframe based on longitude and latitude
gdf_crime_LA = gpd.GeoDataFrame(crime_LA, geometry=gpd.points_from_xy(crime_LA.longitude, crime_LA.latitude))
gdf_crime_LA.head()
# Out:
#   Arrest Date              Location  latitude  longitude  \
# 0  2019-05-03  (33.9543, -118.2827)   33.9543  -118.2827
# 1  2019-04-29  (34.0508, -118.4592)   34.0508  -118.4592
# 2  2019-11-23  (34.0477, -118.2047)   34.0477  -118.2047
# 3  2019-04-30  (34.0907, -118.3384)   34.0907  -118.3384
# 4  2019-04-30  (34.2149, -118.4674)   34.2149  -118.4674
#
#                       geometry
# 0  POINT (-118.28270 33.95430)
# 1  POINT (-118.45920 34.05080)
# 2  POINT (-118.20470 34.04770)
# 3  POINT (-118.33840 34.09070)
# 4  POINT (-118.46740 34.21490)

# %%
# read shapefiles of LA zip code
zipcode_LA =gpd.read_file('data/LosAngeles/Zip Code Areas/geo_export_0cb487cb-63cc-442d-bf7e-53626237722f.shp')
zipcode_LA.head()
# Out:
#    aland10 awater10 classfp10                             display_na  \
# 0  9071359        0        B5  90001 ZIP Code Tabulation Area (2012)
# 1  7930684        0        B5  90002 ZIP Code Tabulation Area (2012)
# 2  9197637      403        B5  90003 ZIP Code Tabulation Area (2012)
# 3  7894525        0        B5  90004 ZIP Code Tabulation Area (2012)
# 4  2807559        0        B5  90005 ZIP Code Tabulation Area (2012)
#
#   external_i funcstat10 geoid10   intptlat10    intptlon10  \
# 0      90001          S   90001  +33.9740268  -118.2495088
# 1      90002          S   90002  +33.9490988  -118.2467371
# 2      90003          S   90003  +33.9641307  -118.2727831
# 3      90004          S   90004  +34.0761981  -118.3107225
# 4      90005          S   90005  +34.0591634  -118.3068924
#
#                               kind mtfcc10   name  \
# 0  ZIP Code Tabulation Area (2012)   G6350  90001
# 1  ZIP Code Tabulation Area (2012)   G6350  90002
# 2  ZIP Code Tabulation Area (2012)   G6350  90003
# 3  ZIP Code Tabulation Area (2012)   G6350  90004
# 4  ZIP Code Tabulation Area (2012)   G6350  90005
#
#                                 set                                 slug  \
# 0  ZIP Code Tabulation Areas (2012)  90001-zip-code-tabulation-area-2012
# 1  ZIP Code Tabulation Areas (2012)  90002-zip-code-tabulation-area-2012
# 2  ZIP Code Tabulation Areas (2012)  90003-zip-code-tabulation-area-2012
# 3  ZIP Code Tabulation Areas (2012)  90004-zip-code-tabulation-area-2012
# 4  ZIP Code Tabulation Areas (2012)  90005-zip-code-tabulation-area-2012
#
#   zcta5ce10                                           geometry
# 0     90001  POLYGON ((-118.26515 33.97025, -118.26517 33.9...
# 1     90002  POLYGON ((-118.23737 33.95852, -118.23737 33.9...
# 2     90003  POLYGON ((-118.26517 33.98183, -118.26298 33.9...
# 3     90004  POLYGON ((-118.31160 34.06896, -118.33773 34.0...
# 4     90005  MULTIPOLYGON (((-118.29164 34.06179, -118.2899...

# %%
# spatial joint crime data with zip code
gdf_crime_LA.crs = zipcode_LA.crs
crime_zip_LA = gpd.sjoin(gdf_crime_LA, zipcode_LA, how="inner", op="intersects")
crime_zip_LA.head()
# Out:
#     Arrest Date              Location  latitude  longitude  \
# 0    2019-05-03  (33.9543, -118.2827)   33.9543  -118.2827
# 13   2019-11-27  (33.9601, -118.2827)   33.9601  -118.2827
# 17   2019-11-21  (33.9798, -118.2827)   33.9798  -118.2827
# 126  2019-04-20  (33.9774, -118.2827)   33.9774  -118.2827
# 127  2019-04-19  (33.9792, -118.2893)   33.9792  -118.2893
#
#                         geometry  index_right   aland10 awater10 classfp10  \
# 0    POINT (-118.28270 33.95430)           41  13303666        0        B5
# 13   POINT (-118.28270 33.96010)           41  13303666        0        B5
# 17   POINT (-118.28270 33.97980)           41  13303666        0        B5
# 126  POINT (-118.28270 33.97740)           41  13303666        0        B5
# 127  POINT (-118.28930 33.97920)           41  13303666        0        B5
#
#                                 display_na  ... funcstat10 geoid10  \
# 0    90044 ZIP Code Tabulation Area (2012)  ...          S   90044
# 13   90044 ZIP Code Tabulation Area (2012)  ...          S   90044
# 17   90044 ZIP Code Tabulation Area (2012)  ...          S   90044
# 126  90044 ZIP Code Tabulation Area (2012)  ...          S   90044
# 127  90044 ZIP Code Tabulation Area (2012)  ...          S   90044
#
#       intptlat10    intptlon10                             kind mtfcc10  \
# 0    +33.9527248  -118.2919037  ZIP Code Tabulation Area (2012)   G6350
# 13   +33.9527248  -118.2919037  ZIP Code Tabulation Area (2012)   G6350
# 17   +33.9527248  -118.2919037  ZIP Code Tabulation Area (2012)   G6350
# 126  +33.9527248  -118.2919037  ZIP Code Tabulation Area (2012)   G6350
# 127  +33.9527248  -118.2919037  ZIP Code Tabulation Area (2012)   G6350
#
#       name                               set  \
# 0    90044  ZIP Code Tabulation Areas (2012)
# 13   90044  ZIP Code Tabulation Areas (2012)
# 17   90044  ZIP Code Tabulation Areas (2012)
# 126  90044  ZIP Code Tabulation Areas (2012)
# 127  90044  ZIP Code Tabulation Areas (2012)
#
#                                     slug zcta5ce10
# 0    90044-zip-code-tabulation-area-2012     90044
# 13   90044-zip-code-tabulation-area-2012     90044
# 17   90044-zip-code-tabulation-area-2012     90044
# 126  90044-zip-code-tabulation-area-2012     90044
# 127  90044-zip-code-tabulation-area-2012     90044
#
# [5 rows x 21 columns]

# %%
# count arrests in each zip code as crime indicator
crime_count_LA = pd.pivot_table(crime_zip_LA,values='Location', index='name', aggfunc='count') \
                   .rename(columns={'Location':'crime'})
crime_count_LA
# Out:
#        crime
# name
# 90001    366
# 90002    803
# 90003   2677
# 90004   1312
# 90005    603
# ...      ...
# 91605   1410
# 91606   1008
# 91607    308
# 91608     43
# 91801      2
#
# [137 rows x 1 columns]

# %% [markdown]
# ## 4. Merge crime indicator to the listings data

# %%
listings_with_IncEduCri_LA = listings_with_edu_income.merge(crime_count_LA, left_on='zipcode',right_index=True)
listings_with_IncEduCri_LA
# Out:
#        Unnamed: 0        id                            listing_url  \
# 2             2.0      2708      https://www.airbnb.com/rooms/2708
# 9             9.0      6931      https://www.airbnb.com/rooms/6931
# 76           76.0     50005     https://www.airbnb.com/rooms/50005
# 88           88.0     61153     https://www.airbnb.com/rooms/61153
# 150         150.0    132908    https://www.airbnb.com/rooms/132908
# ...           ...       ...                                    ...
# 38111     38134.0  41823064  https://www.airbnb.com/rooms/41823064
# 38113     38136.0  41823240  https://www.airbnb.com/rooms/41823240
# 38661     38684.0  42145957  https://www.airbnb.com/rooms/42145957
# 23023     23049.0  29653320  https://www.airbnb.com/rooms/29653320
# 37145     37168.0  41293190  https://www.airbnb.com/rooms/41293190
#
#             scrape_id last_scraped  \
# 2      20200213032707   2020-02-13
# 9      20200213032707   2020-02-13
# 76     20200213032707   2020-02-13
# 88     20200213032707   2020-02-13
# 150    20200213032707   2020-02-13
# ...               ...          ...
# 38111  20200213032707   2020-02-13
# 38113  20200213032707   2020-02-13
# 38661  20200213032707   2020-02-13
# 23023  20200213032707   2020-02-13
# 37145  20200213032707   2020-02-13
#
#                                                name_left  \
# 2      Mirrored Mini-Suite with Fireplace - W. Hollywood
# 9      Off Sunset Wrap-Around Terr Runyon Canyon View...
# 76                       Guest House - Nightly or Weekly
# 88     Gorgeous Furnished Bedroom in Hollywood Hills ...
# 150             Spectacular Home With Breath Taking View
# ...                                                  ...
# 38111                      Super comfortable and cozy!!!
# 38113                              Cozy and Comfortable!
# 38661                Welcome you to stay at my XX hostel
# 23023  Ollie's Place: Diamond in the rough in central LA
# 37145                                         Quiet room
#
#                                                  summary  \
# 2      Our best memory foam pillows you'll ever sleep...
# 9      Our best memory foam pillows; you'll ever slee...
# 76     Private cozy Guest House in a great location. ...
# 88     Great style and comfort in the spacious 4000 s...
# 150    A true Mountain Oasis. 180 degree views nestle...
# ...                                                  ...
# 38111                                                NaN
# 38113                                                NaN
# 38661  Brand New House in Downtown LA!! Big Opening D...
# 23023  Fully updated 2 bedroom/1 bath home! 5 miles f...
# 37145  The 110 fwy is about 2 miles ,a lot of Restaur...
#
#                                                    space  \
# 2      Flickering fireplace.  Blendtec® Designer 625 ...
# 9      Decorated with fresh flowers for the Holidays....
# 76     Retreat in the heart of Hollywood - 1/2 block ...
# 88     One of the most Prestigious and Safest areas i...
# 150    The view is a killer no doubt about it, as it ...
# ...                                                  ...
# 38111                                                NaN
# 38113                                                NaN
# 38661  There are 2 to 4 bunk beds in each room. Mix G...
# 23023                                                NaN
# 37145                                                NaN
#
#                                              description experiences_offered  \
# 2      Our best memory foam pillows you'll ever sleep...                none
# 9      Our best memory foam pillows; you'll ever slee...                none
# 76     Private cozy Guest House in a great location. ...                none
# 88     Great style and comfort in the spacious 4000 s...                none
# 150    A true Mountain Oasis. 180 degree views nestle...                none
# ...                                                  ...                 ...
# 38111                                                NaN                none
# 38113                                                NaN                none
# 38661  Brand New House in Downtown LA!! Big Opening D...                none
# 23023  Fully updated 2 bedroom/1 bath home! 5 miles f...                none
# 37145  The 110 fwy is about 2 miles ,a lot of Restaur...                none
#
#        ... reviews_per_month                     geometry index_right  \
# 2      ...              0.33  POINT (-118.34602 34.09768)           3
# 9      ...              0.14  POINT (-118.34801 34.09521)           3
# 76     ...              0.94  POINT (-118.34985 34.09596)           3
# 88     ...              0.11  POINT (-118.38127 34.11046)           3
# 150    ...              2.15  POINT (-118.37002 34.10456)           3
# ...    ...               ...                          ...         ...
# 38111  ...               NaN  POINT (-118.24911 34.00848)           8
# 38113  ...               NaN  POINT (-118.25017 34.00779)           8
# 38661  ...               NaN  POINT (-118.25897 34.02535)           8
# 23023  ...              0.96  POINT (-118.26157 33.97314)           8
# 37145  ...              3.43  POINT (-118.26243 33.97469)           8
#
#                      dist_name district           name_right objectid  \
# 2                4 - David Ryu      4.0            David Ryu      4.0
# 9                4 - David Ryu      4.0            David Ryu      4.0
# 76               4 - David Ryu      4.0            David Ryu      4.0
# 88               4 - David Ryu      4.0            David Ryu      4.0
# 150              4 - David Ryu      4.0            David Ryu      4.0
# ...                        ...      ...                  ...      ...
# 38111  9 - Curren D. Price Jr.      9.0  Curren D. Price Jr.      9.0
# 38113  9 - Curren D. Price Jr.      9.0  Curren D. Price Jr.      9.0
# 38661  9 - Curren D. Price Jr.      9.0  Curren D. Price Jr.      9.0
# 23023  9 - Curren D. Price Jr.      9.0  Curren D. Price Jr.      9.0
# 37145  9 - Curren D. Price Jr.      9.0  Curren D. Price Jr.      9.0
#
#           income education  crime
# 2      66771.866  0.958282    641
# 9      66771.866  0.958282    641
# 76     66771.866  0.958282    641
# 88     66771.866  0.958282    641
# 150    66771.866  0.958282    641
# ...          ...       ...    ...
# 38111  33327.804  0.716395   2335
# 38113  33327.804  0.716395   2335
# 38661  33327.804  0.716395   2335
# 23023  33327.804  0.716395    366
# 37145  33327.804  0.716395    366
#
# [22413 rows x 116 columns]

# %%
listings_with_IncEduCri_LA.to_csv('listings_with_IncEduCri_LA.csv')

# %% [markdown]
# # New York

# %% [markdown]
# # 0. Import listings data merged with income and education indicators

# %%
listings_with_edu_income_NYC = pd.read_csv('data/NewYork/nyc_merged.csv')
listings_with_edu_income_NYC['income'] = listings_with_edu_income_NYC['IncomePerCapita']
listings_with_edu_income_NYC['education'] = listings_with_edu_income_NYC['EduAboveHS(%)']
listings_with_edu_income_NYC = listings_with_edu_income_NYC.drop(columns=['IncomePerCapita', 'EduAboveHS(%)'])
listings_with_edu_income_NYC.head()
# Out:
#    Unnamed: 0  Zipcode        id                          listing_url  \
# 0           0    10001   15396.0   https://www.airbnb.com/rooms/15396
# 1           1    10001   37042.0   https://www.airbnb.com/rooms/37042
# 2           2    10001   51572.0   https://www.airbnb.com/rooms/51572
# 3           3    10001   98663.0   https://www.airbnb.com/rooms/98663
# 4           4    10001  110739.0  https://www.airbnb.com/rooms/110739
#
#       scrape_id last_scraped  \
# 0  2.020021e+13   2020-02-12
# 1  2.020021e+13   2020-02-12
# 2  2.020021e+13   2020-02-13
# 3  2.020021e+13   2020-02-12
# 4  2.020021e+13   2020-02-13
#
#                                                 name  \
# 0                 Sunny & Spacious Chelsea Apartment
# 1         2BR Flex in Hudson Yards near Penn Station
# 2                        Prime Location in Manhattan
# 3                             Groovy NYC Chelsea Pad
# 4  Central Nomad/Chelsea Loft Studio - metro dnst...
#
#                                              summary  \
# 0  Modern, spacious, bright and well designed apa...
# 1  Close to everything NYC has to offer, the APT ...
# 2  Private Room located on w 30th st right near P...
# 3  Hello! This listing is only available to book ...
# 4  Long terms discounts available.  Spacious and ...
#
#                                                space  \
# 0                                                NaN
# 1  Fully furnished bedrooms in a 24/7 doorman ele...
# 2  My space offers a private bedroom in my 2 bedr...
# 3  Hello! Thanks for checking out my place. I am ...
# 4  This is a very central, large loft-like studio...
#
#                                          description  ...  \
# 0  Modern, spacious, bright and well designed apa...  ...
# 1  Close to everything NYC has to offer, the APT ...  ...
# 2  Private Room located on w 30th st right near P...  ...
# 3  Hello! This listing is only available to book ...  ...
# 4  Long terms discounts available.  Spacious and ...  ...
#
#            cancellation_policy require_guest_profile_picture  \
# 0  strict_14_with_grace_period                             f
# 1                     moderate                             f
# 2  strict_14_with_grace_period                             t
# 3                     moderate                             f
# 4  strict_14_with_grace_period                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                            1.0
# 1                                f                            1.0
# 2                                t                            1.0
# 3                                f                            1.0
# 4                                f                            1.0
#
#   calculated_host_listings_count_entire_homes  \
# 0                                         1.0
# 1                                         1.0
# 2                                         0.0
# 3                                         1.0
# 4                                         1.0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                          0.0
# 1                                          0.0
# 2                                          1.0
# 3                                          0.0
# 4                                          0.0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month   income  \
# 0                                         0.0              0.11  77512.0
# 1                                         0.0              0.21  77512.0
# 2                                         0.0              3.47  77512.0
# 3                                         0.0              0.18  77512.0
# 4                                         0.0              0.57  77512.0
#
#   education
# 0  0.914931
# 1  0.914931
# 2  0.914931
# 3  0.914931
# 4  0.914931
#
# [5 rows x 109 columns]

# %% [markdown]
# ## 1. Calculate crime indicator

# %%
crime_NYC = pd.read_csv('data/NewYork/NYC_2019_Arrest.csv')
crime_NYC
# Out:
#        ARREST_DATE   Latitude  Longitude  year
# 0       09/07/2019  40.674583 -73.930222  2019
# 1       12/22/2019  40.627978 -73.941647  2019
# 2       12/31/2019  40.841085 -73.939769  2019
# 3       12/31/2019  40.596012 -73.742116  2019
# 4       12/31/2019  40.789803 -73.952289  2019
# ...            ...        ...        ...   ...
# 214612  01/01/2019  40.766905 -73.963731  2019
# 214613  01/01/2019  40.673777 -73.763806  2019
# 214614  01/01/2019  40.674632 -73.939378  2019
# 214615  01/01/2019  40.645023 -74.077217  2019
# 214616  01/01/2019  40.762843 -73.991284  2019
#
# [214617 rows x 4 columns]

# %%
# create geodataframe based on longitude and latitude
gdf_crime_NYC = gpd.GeoDataFrame(crime_NYC, geometry=gpd.points_from_xy(crime_NYC.Longitude, crime_NYC.Latitude))
gdf_crime_NYC.head()
# Out:
#   ARREST_DATE   Latitude  Longitude  year                    geometry
# 0  09/07/2019  40.674583 -73.930222  2019  POINT (-73.93022 40.67458)
# 1  12/22/2019  40.627978 -73.941647  2019  POINT (-73.94165 40.62798)
# 2  12/31/2019  40.841085 -73.939769  2019  POINT (-73.93977 40.84108)
# 3  12/31/2019  40.596012 -73.742116  2019  POINT (-73.74212 40.59601)
# 4  12/31/2019  40.789803 -73.952289  2019  POINT (-73.95229 40.78980)

# %%
# read shapefiles of NYC zip code
zipcode_NYC =gpd.read_file('data/NewYork/cb_2018_us_zcta510_500k/cb_2018_us_zcta510_500k.shp')
zipcode_NYC.head()
# Out:
#   ZCTA5CE10      AFFGEOID10 GEOID10    ALAND10  AWATER10  \
# 0     36083  8600000US36083   36083  659750662   5522919
# 1     35441  8600000US35441   35441  172850429   8749105
# 2     35051  8600000US35051   35051  280236456   5427285
# 3     35121  8600000US35121   35121  372736030   5349303
# 4     35058  8600000US35058   35058  178039922   3109259
#
#                                             geometry
# 0  MULTIPOLYGON (((-85.63225 32.28098, -85.62439 ...
# 1  MULTIPOLYGON (((-87.83287 32.84437, -87.83184 ...
# 2  POLYGON ((-86.74384 33.25002, -86.73802 33.251...
# 3  POLYGON ((-86.58527 33.94743, -86.58033 33.948...
# 4  MULTIPOLYGON (((-86.87884 34.21196, -86.87649 ...

# %%
# spatial joint crime data with zip code
gdf_crime_NYC.crs = zipcode_NYC.crs
crime_zip_NYC = gpd.sjoin(gdf_crime_NYC, zipcode_NYC, how="inner", op="intersects")
crime_zip_NYC.head()
# Out:
#     ARREST_DATE   Latitude  Longitude  year                    geometry  \
# 0    09/07/2019  40.674583 -73.930222  2019  POINT (-73.93022 40.67458)
# 91   12/31/2019  40.676981 -73.937310  2019  POINT (-73.93731 40.67698)
# 353  12/30/2019  40.668959 -73.933890  2019  POINT (-73.93389 40.66896)
# 416  12/30/2019  40.667909 -73.932600  2019  POINT (-73.93260 40.66791)
# 424  12/30/2019  40.674600 -73.930575  2019  POINT (-73.93057 40.67460)
#
#      index_right ZCTA5CE10      AFFGEOID10 GEOID10  ALAND10  AWATER10
# 0          25730     11213  8600000US11213   11213  2824121         0
# 91         25730     11213  8600000US11213   11213  2824121         0
# 353        25730     11213  8600000US11213   11213  2824121         0
# 416        25730     11213  8600000US11213   11213  2824121         0
# 424        25730     11213  8600000US11213   11213  2824121         0

# %%
# count arrests in each zip code as crime indicator
crime_count_NYC = pd.pivot_table(crime_zip_NYC,values='geometry', index='ZCTA5CE10', aggfunc='count') \
                   .rename(columns={'geometry':'crime'})
crime_count_NYC
# Out:
#            crime
# ZCTA5CE10
# 10001       2846
# 10002       2721
# 10003       1817
# 10004        163
# 10005         93
# ...          ...
# 11691       1941
# 11692        549
# 11693        724
# 11694        272
# 11697          4
#
# [210 rows x 1 columns]

# %% [markdown]
# ## 2. Merge crime indicator to the listings data

# %%
crime_count_NYC.index = crime_count_NYC.index.astype('int64')

# %%
listings_with_IncEduCri_NYC = listings_with_edu_income_NYC.merge(crime_count_NYC, left_on='Zipcode',right_index=True)
listings_with_IncEduCri_NYC
# Out:
#        Unnamed: 0  Zipcode          id                            listing_url  \
# 0               0    10001     15396.0     https://www.airbnb.com/rooms/15396
# 1               1    10001     37042.0     https://www.airbnb.com/rooms/37042
# 2               2    10001     51572.0     https://www.airbnb.com/rooms/51572
# 3               3    10001     98663.0     https://www.airbnb.com/rooms/98663
# 4               4    10001    110739.0    https://www.airbnb.com/rooms/110739
# ...           ...      ...         ...                                    ...
# 49486       49486    11694  36417725.0  https://www.airbnb.com/rooms/36417725
# 49487       49487    11694  38059680.0  https://www.airbnb.com/rooms/38059680
# 49488       49488    11697         NaN                                    NaN
# 50262       50262    10174  20933849.0  https://www.airbnb.com/rooms/20933849
# 50264       50264    10550  21602731.0  https://www.airbnb.com/rooms/21602731
#
#           scrape_id last_scraped  \
# 0      2.020021e+13   2020-02-12
# 1      2.020021e+13   2020-02-12
# 2      2.020021e+13   2020-02-13
# 3      2.020021e+13   2020-02-12
# 4      2.020021e+13   2020-02-13
# ...             ...          ...
# 49486  2.020021e+13   2020-02-13
# 49487  2.020021e+13   2020-02-13
# 49488           NaN          NaN
# 50262  2.020021e+13   2020-02-12
# 50264  2.020021e+13   2020-02-13
#
#                                                     name  \
# 0                     Sunny & Spacious Chelsea Apartment
# 1             2BR Flex in Hudson Yards near Penn Station
# 2                            Prime Location in Manhattan
# 3                                 Groovy NYC Chelsea Pad
# 4      Central Nomad/Chelsea Loft Studio - metro dnst...
# ...                                                  ...
# 49486                       Ocenfront Glamping in Queens
# 49487     Cute two bedroom beach suite in Rockaway Beach
# 49488                                                NaN
# 50262                              the best you can find
# 50264     Spacious 1 bedroom in lower Westchester County
#
#                                                  summary  \
# 0      Modern, spacious, bright and well designed apa...
# 1      Close to everything NYC has to offer, the APT ...
# 2      Private Room located on w 30th st right near P...
# 3      Hello! This listing is only available to book ...
# 4      Long terms discounts available.  Spacious and ...
# ...                                                  ...
# 49486                                                NaN
# 49487  This is a cute little guest suite just three h...
# 49488                                                NaN
# 50262                                                NaN
# 50264  Ground floor apartment with a queen size bed, ...
#
#                                                    space  \
# 0                                                    NaN
# 1      Fully furnished bedrooms in a 24/7 doorman ele...
# 2      My space offers a private bedroom in my 2 bedr...
# 3      Hello! Thanks for checking out my place. I am ...
# 4      This is a very central, large loft-like studio...
# ...                                                  ...
# 49486                                                NaN
# 49487  Our cute little space is just steps from the b...
# 49488                                                NaN
# 50262                                                NaN
# 50264  One bedroom with a queen sized bed, a small lo...
#
#                                              description  ...  \
# 0      Modern, spacious, bright and well designed apa...  ...
# 1      Close to everything NYC has to offer, the APT ...  ...
# 2      Private Room located on w 30th st right near P...  ...
# 3      Hello! This listing is only available to book ...  ...
# 4      Long terms discounts available.  Spacious and ...  ...
# ...                                                  ...  ...
# 49486                                                NaN  ...
# 49487  This is a cute little guest suite just three h...  ...
# 49488                                                NaN  ...
# 50262                                                NaN  ...
# 50264  Ground floor apartment with a queen size bed, ...  ...
#
#       require_guest_profile_picture require_guest_phone_verification  \
# 0                                 f                                f
# 1                                 f                                f
# 2                                 t                                t
# 3                                 f                                f
# 4                                 f                                f
# ...                             ...                              ...
# 49486                             f                                f
# 49487                             f                                f
# 49488                           NaN                              NaN
# 50262                             f                                f
# 50264                             f                                f
#
#       calculated_host_listings_count  \
# 0                                1.0
# 1                                1.0
# 2                                1.0
# 3                                1.0
# 4                                1.0
# ...                              ...
# 49486                            1.0
# 49487                            1.0
# 49488                            NaN
# 50262                            1.0
# 50264                            1.0
#
#       calculated_host_listings_count_entire_homes  \
# 0                                             1.0
# 1                                             1.0
# 2                                             0.0
# 3                                             1.0
# 4                                             1.0
# ...                                           ...
# 49486                                         0.0
# 49487                                         1.0
# 49488                                         NaN
# 50262                                         1.0
# 50264                                         1.0
#
#       calculated_host_listings_count_private_rooms  \
# 0                                              0.0
# 1                                              0.0
# 2                                              1.0
# 3                                              0.0
# 4                                              0.0
# ...                                            ...
# 49486                                          1.0
# 49487                                          0.0
# 49488                                          NaN
# 50262                                          0.0
# 50264                                          0.0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month   income  \
# 0                                             0.0              0.11  77512.0
# 1                                             0.0              0.21  77512.0
# 2                                             0.0              3.47  77512.0
# 3                                             0.0              0.18  77512.0
# 4                                             0.0              0.57  77512.0
# ...                                           ...               ...      ...
# 49486                                         0.0               NaN  37351.0
# 49487                                         0.0              1.90  37351.0
# 49488                                         NaN               NaN  39540.0
# 50262                                         0.0               NaN      NaN
# 50264                                         0.0              2.51      NaN
#
#       education crime
# 0      0.914931  2846
# 1      0.914931  2846
# 2      0.914931  2846
# 3      0.914931  2846
# 4      0.914931  2846
# ...         ...   ...
# 49486  0.882391   272
# 49487  0.882391   272
# 49488  0.955157     4
# 50262       NaN     9
# 50264       NaN     1
#
# [49491 rows x 110 columns]

# %%
listings_with_IncEduCri_NYC.to_csv('listings_with_IncEduCri_NYC.csv')
